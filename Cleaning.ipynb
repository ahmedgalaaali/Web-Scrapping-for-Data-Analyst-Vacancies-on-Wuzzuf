# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import re

# %%
df = pd.read_csv(r"C:\Mine\FreeCodeCamp Web Scrapping\wuzzuf_data_analyst.csv")
df.head()
# Out:
#                              job_title                   company_name  \
# 0               Financial Data Analyst                      ECC Group
# 1  Manager - Data Intelligence Analyst                      Almosafer
# 2            Supply Chain Data Analyst                     ZeroCarbon
# 3                         Data Analyst  Specialized Seamless Services
# 4                         Data Analyst                   Venus Hiring
#
#                    location     duration   job_type job_status        level  \
# 0   Nasr City, Cairo, Egypt   4 days ago  Full Time    On-site  Experienced
# 1  Mohandessin, Giza, Egypt   6 days ago  Full Time    On-site      Manager
# 2              Cairo, Egypt   7 days ago  Full Time    On-site  Experienced
# 3  Heliopolis, Cairo, Egypt   3 days ago  Full Time    On-site  Entry Level
# 4           Toronto, Canada  13 days ago  Full Time    On-site  Entry Level
#
#   years_of_experience                                    skills_required
# 0              3 - 5   Experienced · 3 - 5 Yrs of Exp · Education/Tea...
# 1              5 - 8   Manager · 5 - 8 Yrs of Exp · Analyst/Research ...
# 2              2 - 3   Experienced · 2 - 3 Yrs of Exp · Logistics/Sup...
# 3              2 - 4   Entry Level · 2 - 4 Yrs of Exp · Administratio...
# 4              1 - 5   Entry Level · 1 - 5 Yrs of Exp · Analyst/Resea...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219 entries, 0 to 218
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   job_title            219 non-null    object
#  1   company_name         219 non-null    object
#  2   location             219 non-null    object
#  3   duration             219 non-null    object
#  4   job_type             219 non-null    object
#  5   job_status           219 non-null    object
#  6   level                219 non-null    object
#  7   years_of_experience  219 non-null    object
#  8   skills_required      219 non-null    object
# dtypes: object(9)
# memory usage: 15.5+ KB

# %% [markdown]
# ## Major modifications
# #### 1. `Duration` column:
# - Create new column called date.
# - Calculate the date when the job was posted.
# - Remove any unvalid data from the column.
# - Delete `duration` column.
#
# #### 2. `Years of Experience` column
# - Replace all the invalid values with NaN.
#
# #### 3. `Skills Required` column:
# - Remove extra text from the cells.
# - Put the skills into lists.

# %%
df[["num_days", "day_month", "ago"]]=df.duration.str.split(expand=True)
df[["num_days", "day_month", "ago"]]
# Out:
#     num_days day_month  ago
# 0          4      days  ago
# 1          6      days  ago
# 2          7      days  ago
# 3          3      days  ago
# 4         13      days  ago
# ..       ...       ...  ...
# 214        2    months  ago
# 215        2    months  ago
# 216        7      days  ago
# 217        7      days  ago
# 218        5      days  ago
#
# [219 rows x 3 columns]

# %%
df.num_days = df.num_days.astype(int)

# %%
df["days"] = df.apply(lambda x: x["num_days"]*30 if x["day_month"] == "months" else x["num_days"], axis=1)

# %%
df["month_posted"] = df.apply(lambda x: (datetime.today() - timedelta(days=x["days"])).strftime("%B"), axis=1)

# %%
df.drop(columns=["num_days", "day_month", "ago", "days", "duration"], inplace=True)

# %%
df[["exp_from", "exp_to"]]=df["years_of_experience"].str.split(" - ", expand=True)
df[["exp_from", "exp_to"]]
# Out:
#                   exp_from exp_to
# 0                        3     5
# 1                        5     8
# 2                        2     3
# 3                        2     4
# 4                        1     5
# ..                     ...    ...
# 214                      3     5
# 215                      4     6
# 216  Riyadh, Saudi Arabia    None
# 217           Doha, Qatar    None
# 218                  Cairo   None
#
# [219 rows x 2 columns]

# %%
df.exp_to.unique()
# Out:
# array(['5 ', '8 ', '3 ', '4 ', None, '15 ', '7 ', '9 ', '6 ', '1 ', '2 ',
#        '10 ', '20 ', '13 ', '12 ', '14 '], dtype=object)

# %%
df["experience"] = df.apply(lambda x: x.exp_from + "-" + x.exp_to if len(x.exp_from) <= 2 else "Not specified", axis=1)
df["experience"]
# Out:
# 0               3-5
# 1               5-8
# 2               2-3
# 3               2-4
# 4               1-5
#            ...
# 214             3-5
# 215             4-6
# 216    Not specified
# 217    Not specified
# 218    Not specified
# Name: experience, Length: 219, dtype: object

# %%
df.drop(columns=["years_of_experience", "exp_from", "exp_to"], inplace=True)

# %%
df["skills_required"] = df["skills_required"].map(lambda x: re.sub(r'^.*Yrs of Exp\s*·\s*', '', x))

# %%
df["skills_required"] = df["skills_required"].str.split(" · ")

# %%
df
# Out:
#                                         job_title  \
# 0                          Financial Data Analyst
# 1             Manager - Data Intelligence Analyst
# 2                       Supply Chain Data Analyst
# 3                                    Data Analyst
# 4                                    Data Analyst
# ..                                            ...
# 214                                Tax Accountant
# 215          Financial Planning And Analysis Head
# 216                          Senior ETL Developer
# 217                       Senior Report Developer
# 218  Technical Architect (SAP S/4HANA) (JO021233)
#
#                                 company_name                  location  \
# 0                                  ECC Group   Nasr City, Cairo, Egypt
# 1                                  Almosafer  Mohandessin, Giza, Egypt
# 2                                 ZeroCarbon              Cairo, Egypt
# 3              Specialized Seamless Services  Heliopolis, Cairo, Egypt
# 4                               Venus Hiring           Toronto, Canada
# ..                                       ...                       ...
# 214                                  DC Auto       Maadi, Cairo, Egypt
# 215    Easy Group For Health and Beauty Care         Alexandria, Egypt
# 216                             Master-Works      Riyadh, Saudi Arabia
# 217  El Seif Engineering Contracting Company      Riyadh, Saudi Arabia
# 218                               MphExperts               Doha, Qatar
#
#       job_type     job_status          level  \
# 0    Full Time        On-site    Experienced
# 1    Full Time        On-site        Manager
# 2    Full Time        On-site    Experienced
# 3    Full Time        On-site    Entry Level
# 4    Full Time        On-site    Entry Level
# ..         ...            ...            ...
# 214  Full Time        On-site    Experienced
# 215  Full Time        On-site    Experienced
# 216  Full Time  Not specified  Not specified
# 217  Full Time  Not specified  Not specified
# 218  Full Time  Not specified  Not specified
#
#                                        skills_required month_posted  \
# 0    [Education/Teaching, Data, CFA, Analyst, Finance]        March
# 1    [Analyst/Research, Tourism/Travel, Power BI, Q...        March
# 2    [Logistics/Supply Chain, Analyst/Research, bus...        March
# 3    [Administration, Analyst/Research, Microsoft O...        March
# 4    [Analyst/Research, Engineering - Telecom/Techn...        March
# ..                                                 ...          ...
# 214  [Accounting/Finance, Accounting, accountant, T...      January
# 215  [Accounting/Finance, Business Development, Ana...      January
# 216  [Not specified, Business Development, IT/Softw...        March
# 217  [Not specified, Business Development, IT/Softw...        March
# 218  [Not specified, Engineering - Construction/Civ...        March
#
#         experience
# 0             3-5
# 1             5-8
# 2             2-3
# 3             2-4
# 4             1-5
# ..             ...
# 214           3-5
# 215           4-6
# 216  Not specified
# 217  Not specified
# 218  Not specified
#
# [219 rows x 9 columns]

# %%
df = df[["job_title", "job_type", "company_name", "location", "job_status","level", "experience", "month_posted", "skills_required"]]
df.head()
# Out:
#                              job_title   job_type  \
# 0               Financial Data Analyst  Full Time
# 1  Manager - Data Intelligence Analyst  Full Time
# 2            Supply Chain Data Analyst  Full Time
# 3                         Data Analyst  Full Time
# 4                         Data Analyst  Full Time
#
#                     company_name                  location job_status  \
# 0                      ECC Group   Nasr City, Cairo, Egypt    On-site
# 1                      Almosafer  Mohandessin, Giza, Egypt    On-site
# 2                     ZeroCarbon              Cairo, Egypt    On-site
# 3  Specialized Seamless Services  Heliopolis, Cairo, Egypt    On-site
# 4                   Venus Hiring           Toronto, Canada    On-site
#
#          level experience month_posted  \
# 0  Experienced       3-5         March
# 1      Manager       5-8         March
# 2  Experienced       2-3         March
# 3  Entry Level       2-4         March
# 4  Entry Level       1-5         March
#
#                                      skills_required
# 0  [Education/Teaching, Data, CFA, Analyst, Finance]
# 1  [Analyst/Research, Tourism/Travel, Power BI, Q...
# 2  [Logistics/Supply Chain, Analyst/Research, bus...
# 3  [Administration, Analyst/Research, Microsoft O...
# 4  [Analyst/Research, Engineering - Telecom/Techn...

# %%
df.month_posted.unique()
# Out:
# array(['March', 'February', 'January'], dtype=object)

# %%
df.to_excel("C:\Mine\FreeCodeCamp Web Scrapping\wuzzuf_data_analyst_Q1_2025.xlsx", index=False, header=True)

# %%
with open(r"C:\Mine\FreeCodeCamp Web Scrapping\Confirmation.txt", "w") as file:
    file.write(f"Data size: {len(df)}" + "/n")
    file.write(f"Months jobs published: {df["month_posted"].unique()}")
